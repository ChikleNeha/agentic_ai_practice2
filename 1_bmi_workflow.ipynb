# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
class BMIState(TypedDict):
    height_m : float
    weight_kg : float
    bmi : float

# %%
def bmi_calc(state:BMIState) -> BMIState :

    height = state['height_m']
    weight = state['weight_kg']

    bmi = weight / (height**2)

    state['bmi'] = bmi

    return state

# %%
graph = StateGraph(BMIState)

# aadding nodes
graph.add_node("bmi_calc", bmi_calc)

# adding edges
graph.add_edge(START, "bmi_calc")
graph.add_edge("bmi_calc", END)

workflow = graph.compile()

# %%
initial_state = {"height_m": 1.7, "weight_kg": 50}

final_state = workflow.invoke(initial_state)

# %%
print(final_state)
# Out:
# {'height_m': 1.7, 'weight_kg': 50, 'bmi': 17.301038062283737}
